# %% [markdown]
# # Preparation of GWR - Data

# %% [markdown]
# ## Libraries and Settings

# %%
# Libraries
import os
import json
import folium
import requests
import numpy as np
import pandas as pd
import geopandas as gpd
from datetime import date

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print(os.getcwd())
# Out:
# /workspaces/spatial_data_analysis/05_Python_GWR_Data

# %% [markdown]
# ## Download GWR data
#
# Source: https://public.madd.bfs.admin.ch

# %%
# Download latest file for the Canton of Zurich
url = "https://public.madd.bfs.admin.ch/buildings_zh.geojson"
response = requests.get(url)

# Ensure response is valid
if response.status_code == 200:
    # Open file in write mode and write the response content
    with open('buildings_zh.geojson', 'wb') as file:
        file.write(response.content)
else:
    print(f"Failed to download file, status code: {response.status_code}")

# %% [markdown]
# ## Import latest GWR Data

# %%
# Load json file
with open('buildings_zh.geojson') as f:
    data = json.load(f)

# Flatten nested json data
df_orig = pd.json_normalize(data, record_path=['features'])
df_orig

# Remove prefix
df_orig.columns = df_orig.columns.str.replace('properties.', '')
df_orig.columns = df_orig.columns.str.replace('geometry.', '')

# Create copy
df = df_orig.copy()
df.head()
# Out:
#       type   egid  buildingStatus  buildingCategory  buildingClass  \
# 0  Feature      1            1004              1040           1271
# 1  Feature     10            1004              1020           1110
# 2  Feature    100            1004              1020           1110
# 3  Feature   1000            1007              1030           1110
# 4  Feature  10000            1004              1030           1121
#
#    municipalityNumber    municipalityName canton   type  \
# 0                   2  Affoltern am Albis     ZH  Point
# 1                   2  Affoltern am Albis     ZH  Point
# 2                   2  Affoltern am Albis     ZH  Point
# 3                   2  Affoltern am Albis     ZH  Point
# 4                 291         Andelfingen     ZH  Point
#
#                   coordinates
# 0          [2676523, 1235843]
# 1  [2676440.038, 1235973.538]
# 2  [2676765.706, 1236101.658]
# 3  [2676644.881, 1236812.863]
# 4   [2693391.65, 1272255.267]

# %% [markdown]
# ## Separate Swiss LV95 coordinates

# %%
# Separate coordinates
df['x_coords'] = pd.DataFrame(df['coordinates'].tolist(), columns=['x_coord', 'y_coord'])['x_coord']
df['y_coords'] = pd.DataFrame(df['coordinates'].tolist(), columns=['x_coord', 'y_coord'])['y_coord']

# Remove column 'coordinates'
df = df.drop(['coordinates'], axis=1)
df
# Out:
#            type   egid  buildingStatus  buildingCategory  buildingClass  \
# 0       Feature      1            1004              1040           1271
# 1       Feature     10            1004              1020           1110
# 2       Feature    100            1004              1020           1110
# 3       Feature   1000            1007              1030           1110
# 4       Feature  10000            1004              1030           1121
# ...         ...    ...             ...               ...            ...
# 397521  Feature  99995            1004              1040              0
# 397522  Feature  99996            1004              1040              0
# 397523  Feature  99997            1004              1040              0
# 397524  Feature  99998            1004              1040              0
# 397525  Feature  99999            1007              1040              0
#
#         municipalityNumber    municipalityName canton   type     x_coords  \
# 0                        2  Affoltern am Albis     ZH  Point  2676523.000
# 1                        2  Affoltern am Albis     ZH  Point  2676440.038
# 2                        2  Affoltern am Albis     ZH  Point  2676765.706
# 3                        2  Affoltern am Albis     ZH  Point  2676644.881
# 4                      291         Andelfingen     ZH  Point  2693391.650
# ...                    ...                 ...    ...    ...          ...
# 397521                 198               Uster     ZH  Point  2696792.976
# 397522                 198               Uster     ZH  Point  2696718.474
# 397523                 198               Uster     ZH  Point  2696722.040
# 397524                 198               Uster     ZH  Point  2696727.666
# 397525                 198               Uster     ZH  Point  2696710.888
#
#            y_coords
# 0       1235843.000
# 1       1235973.538
# 2       1236101.658
# 3       1236812.863
# 4       1272255.267
# ...             ...
# 397521  1245085.637
# 397522  1245039.536
# 397523  1245043.472
# 397524  1245050.586
# 397525  1245059.793
#
# [397526 rows x 11 columns]

# %% [markdown]
# ## Create WGS84 coordinates

# %%
# Create geodataframe and calculate latitude and longitude
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['x_coords'], df['y_coords']), crs="EPSG:2056")

# Convert the Swiss LV95 coordinates to lat & lon
gdf = gdf.to_crs(epsg=4326)

# Get Latitude and Longitude
df['latitude'] = gdf['geometry'].y
df['longitude'] = gdf['geometry'].x

# Show data
df
# Out:
#            type   egid  buildingStatus  buildingCategory  buildingClass  \
# 0       Feature      1            1004              1040           1271
# 1       Feature     10            1004              1020           1110
# 2       Feature    100            1004              1020           1110
# 3       Feature   1000            1007              1030           1110
# 4       Feature  10000            1004              1030           1121
# ...         ...    ...             ...               ...            ...
# 397521  Feature  99995            1004              1040              0
# 397522  Feature  99996            1004              1040              0
# 397523  Feature  99997            1004              1040              0
# 397524  Feature  99998            1004              1040              0
# 397525  Feature  99999            1007              1040              0
#
#         municipalityNumber    municipalityName canton   type     x_coords  \
# 0                        2  Affoltern am Albis     ZH  Point  2676523.000
# 1                        2  Affoltern am Albis     ZH  Point  2676440.038
# 2                        2  Affoltern am Albis     ZH  Point  2676765.706
# 3                        2  Affoltern am Albis     ZH  Point  2676644.881
# 4                      291         Andelfingen     ZH  Point  2693391.650
# ...                    ...                 ...    ...    ...          ...
# 397521                 198               Uster     ZH  Point  2696792.976
# 397522                 198               Uster     ZH  Point  2696718.474
# 397523                 198               Uster     ZH  Point  2696722.040
# 397524                 198               Uster     ZH  Point  2696727.666
# 397525                 198               Uster     ZH  Point  2696710.888
#
#            y_coords   latitude  longitude
# 0       1235843.000  47.269056   8.449859
# 1       1235973.538  47.270239   8.448785
# 2       1236101.658  47.271354   8.453110
# 3       1236812.863  47.277764   8.451635
# 4       1272255.267  47.594339   8.680355
# ...             ...        ...        ...
# 397521  1245085.637  47.349516   8.719673
# 397522  1245039.536  47.349113   8.718677
# 397523  1245043.472  47.349147   8.718725
# 397524  1245050.586  47.349211   8.718801
# 397525  1245059.793  47.349296   8.718581
#
# [397526 rows x 13 columns]

# %% [markdown]
# ## Match descriptions to buildingCategory &	buildingClass

# %%
# Read .xslx file with the data
df_gwr_cat = pd.read_excel('gkat_translator.xlsx', sheet_name='buildingCategory')
df_gwr_class = pd.read_excel('gkat_translator.xlsx', sheet_name='buildingClass')

# Merge the DataFrames on 'buildingCategory'
df_merged = pd.merge(df, df_gwr_cat, on='buildingCategory', how='left')
df_merged = pd.merge(df_merged, df_gwr_class, on='buildingClass', how='left')

# Show data
df_merged[['egid', 'buildingCategory', 'buildingClass', 'buildingCategoryDesc', 'buildingClassDesc']].head()
# Out:
#     egid  buildingCategory  buildingClass  \
# 0      1              1040           1271
# 1     10              1020           1110
# 2    100              1020           1110
# 3   1000              1030           1110
# 4  10000              1030           1121
#
#                         buildingCategoryDesc  \
# 0        Gebäude mit teilweiser Wohnnutzung
# 1  Gebäude mit ausschliesslicher Wohnnutzung
# 2  Gebäude mit ausschliesslicher Wohnnutzung
# 3               Wohngebäude mit Nebennutzung
# 4               Wohngebäude mit Nebennutzung
#
#                      buildingClassDesc
# 0  Landwirtschaftliche Betriebsgebäude
# 1            Gebäude mit einer Wohnung
# 2            Gebäude mit einer Wohnung
# 3            Gebäude mit einer Wohnung
# 4           Gebäude mit zwei Wohnungen

# %% [markdown]
# ## Plot subset of buildings

# %%
# Subset
df_sub = df_merged.loc[df['municipalityName'] == 'Greifensee'].sample(100).dropna()

# Create the map
m = folium.Map(location=[df_sub['latitude'].mean(), df_sub['longitude'].mean()], zoom_start=15)

# Add points to the map
for idx, row in df_sub.iterrows():
    folium.Marker(location=([row['latitude'], 
                            row['longitude']]),
                  popup=row['buildingClassDesc']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba744bd7ba3ecbc278c1c218b4f77d39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba744bd7ba3ecbc278c1c218b4f77d39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba744bd7ba3ecbc278c1c218b4f77d39 = L.map(
#                 &quot;map_ba744bd7ba3ecbc278c1c218b4f77d39&quot;,
#                 {
#                     center: [47.367186503534604, 8.681175672506797],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24ef6956cdc7166b1526bef054eca688 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_24ef6956cdc7166b1526bef054eca688.addTo(map_ba744bd7ba3ecbc278c1c218b4f77d39);
#
#
#             var marker_97f9816ea09a7e50b7408459e9740b49 = L.marker(
#                 [47.36437078281674, 8.684182613760651],
#                 {
# }
#             ).addTo(map_ba744bd7ba3ecbc278c1c218b4f77d39);
#
#
#         var popup_58864fefb4cf6e6e83aca1ecffc1a1fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43592049044d882718be86e910992756 = $(`&lt;div id=&quot;html_43592049044d882718be86e910992756&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gebäude mit einer Wohnung&lt;/div&gt;`)[0];
#                 popup_58864fefb4cf6e6e83aca1ecffc1a1fb.setContent(html_43592049044d882718be86e910992756);
#
#
#
#         marker_97f9816ea09a7e50b7408459e9740b49.bindPopup(popup_58864fefb4cf6e6e83aca1ecffc1a1fb)
#         ;
#
#
#
#
#             var marker_50ade424445b935240e01c190053d02d = L.marker(
#                 [47.36480830100699, 8.676340277773619],
#                 {
# }
#             ).addTo(map_ba744bd7ba3ecbc278c1c218b4f77d39);
#
#
#         var popup_ccf192f5d9d3e627b361a5b1c7bb8550 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a95e5a2b7bd76d961935fe638835bd1c = $(`&lt;div id=&quot;html_a95e5a2b7bd76d961935fe638835bd1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gebäude mit einer Wohnung&lt;/div&gt;`)[0];
#                 popup_ccf192f5d9d3e627b361a5b1c7bb8550.setContent(html_a95e5a2b7bd76d961935fe638835bd1c);
#
#
#
#         marker_50ade424445b935240e01c190053d02d.bindPopup(popup_ccf192f5d9d3e627b361a5b1c7bb8550)
#         ;
#
#
#
#
#             var marker_fe8f9f964052e3891d3f7d9e40bc58ea = L.marker(
#                 [47.37105923780771, 8.678121481454388],
#                 {
# }
#             ).addTo(map_ba744bd7ba3ecbc278c1c218b4f77d39);
#
#
#         var popup_092cce93613516d04af65a315f1a39cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a18430df091d8768861dc9bf5f13a0d1 = $(`&lt;div id=&quot;html_a18430df091d8768861dc9bf5f13a0d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gebäude mit einer Wohnung&lt;/div&gt;`)[0];
#                 popup_092cce93613516d04af65a315f1a39cc.setContent(html_a18430df091d8768861dc9bf5f13a0d1);
#
#
#
#         marker_fe8f9f964052e3891d3f7d9e40bc58ea.bindPopup(popup_092cce93613516d04af65a315f1a39cc)
#         ;
#
#
#
#
#             var marker_53ebab0b821ef597965c862ea03730b8 = L.marker(
#                 [47.36799887307492, 8.682228766150663],
#                 {
# }
#             ).addTo(map_ba744bd7ba3ecbc278c1c218b4f77d39);
#
#
#         var popup_f824ef38af54921458cd6a961c71e599 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e3046308fcd7811aab851f0859eeb26 = $(`&lt;div id=&quot;html_3e3046308fcd7811aab851f0859eeb26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gebäude mit drei oder mehr Wohnungen&lt;/div&gt;`)[0];
#                 popup_f824ef38af54921458cd6a961c71e599.setContent(html_3e3046308fcd7811aab851f0859eeb26);
#
#
#
#         marker_53ebab0b821ef597965c862ea03730b8.bindPopup(popup_f824ef38af54921458cd6a961c71e599)
#         ;
#
#
#
#
#             var marker_b5eaaeefe10f094f7ffd7219925fd4c6 = L.marker(
#                 [47.368173249815094, 8.681509247315738],
#                 {
# }
#             ).addTo(map_ba744bd7ba3ecbc278c1c218b4f77d39);
#
#
#         var popup_9b284a6a91e78ccb60f216f578b5f664 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4eb93859063a1578807874fbd8ced5b = $(`&lt;div id=&quot;html_e4eb93859063a1578807874fbd8ced5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gebäude mit drei ode

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1030-azure
# Datetime: 2025-09-29 08:09:05
# Python Version: 3.11.13
# -----------------------------------
